# %% [markdown]
# # Flight look-to-book Data Preprocessing
#
# #### @author glin
# #### 15/06/2019

# %%
import pandas as pd

# %% [markdown]
# **Question 1**
#
# Check the number of lines in each of the two files (bookings and searches)

# %%
bookingPath_small = '../data/sample/bookings.csv.small'
bookings_small = pd.read_csv(bookingPath_small, header=0, sep='^')

# %%
bookings_small
# Out:
#    act_date             source  pos_ctry                          pos_iata  \
# 0  2013-03-05 00:00:00  1A      DE        a68dd7ae953c8acfb187a1af2dcbe123
# 1  2013-03-26 00:00:00  1A      US        e612b9eeeee6f17f42d9b0d3b79e75ca
# 2  2013-03-26 00:00:00  1A      US        e612b9eeeee6f17f42d9b0d3b79e75ca
# 3  2013-03-26 00:00:00  1A      AU        0f984b3bb6bd06661c95529bbd6193bc
# 4  2013-03-26 00:00:00  1A      AU        0f984b3bb6bd06661c95529bbd6193bc
# 5  2013-03-20 00:00:00  1V      US        0283592e45e392871f7e14b1e22a9aaf
# 6  2013-03-20 00:00:00  1V      US        0283592e45e392871f7e14b1e22a9aaf
# 7  2013-03-25 00:00:00  1V      JP        5af045902bd23cab579915611d99e1e0
# 8  2013-03-25 00:00:00  1V      JP        5af045902bd23cab579915611d99e1e0
# 9  2013-03-25 00:00:00  1V      JP        5af045902bd23cab579915611d99e1e0
#
#                           pos_oid                      rloc            \
# 0  1a11ae49fcbf545fd2afc1a24d88d2b7  ea65900e72d71f4626378e2ebd298267
# 1  7437560d8f276d6d05eeb806d9e7edee  737295a86982c941f1c2da9a46a14043
# 2  7437560d8f276d6d05eeb806d9e7edee  737295a86982c941f1c2da9a46a14043
# 3  36472c6dbaf7afec9136ac40364e2794  5ecf00fdcbcec761c43dc7285253d0c1
# 4  36472c6dbaf7afec9136ac40364e2794  5ecf00fdcbcec761c43dc7285253d0c1
# 5  2d0f8e7e1bb792625d2f34f221bc38f1  d54708298686de200f8270e7c637af5e
# 6  2d0f8e7e1bb792625d2f34f221bc38f1  d54708298686de200f8270e7c637af5e
# 7  5073861d8597467c33596bfe16f23c56  a37584d1485cb35991e4ff1a2ba92262
# 8  5073861d8597467c33596bfe16f23c56  a37584d1485cb35991e4ff1a2ba92262
# 9  5073861d8597467c33596bfe16f23c56  a37584d1485cb35991e4ff1a2ba92262
#
#    cre_date             duration  distance  dep_port  ...  route            \
# 0  2013-02-22 00:00:00      1708         0  ZRH       ...  LHRZRH
# 1  2013-03-26 00:00:00    135270         0  SAL       ...  SALATLCLT
# 2  2013-03-26 00:00:00    135270         0  SAL       ...  CLTATLSAL
# 3  2013-03-26 00:00:00     30885         0  AKL       ...  AKLHKGSVO
# 4  2013-03-26 00:00:00     30885         0  AKL       ...  SVOHKGAKL
# 5  2013-03-20 00:00:00      5923         0  DEN       ...  DENLGA
# 6  2013-03-20 00:00:00      5923         0  DEN       ...  LGADEN
# 7  2013-03-25 00:00:00      8371        60  NRT       ...  NRTSIN
# 8  2013-03-25 00:00:00      8371        60  NRT       ...  SINPEN
# 9  2013-03-25 00:00:00      8371        60  NRT       ...  PENBKK
#
#   carrier  bkg_class  cab_class  brd_time             off_time            pax  \
# 0      VI  T          Y          2013-03-07 08:50:00  2013-03-07 11:33:37  -1
# 1      NV  L          Y          2013-04-12 13:04:00  2013-04-12 22:05:40   1
# 2      NV  U          Y          2013-07-15 07:00:00  2013-07-15 11:34:51   1
# 3      XK  G          Y          2013-04-24 23:59:00  2013-04-25 16:06:31   1
# 4      XK  G          Y          2013-05-14 20:15:00  2013-05-16 10:44:50   1
# 5      FK  W          Y          2013-04-07 10:23:00  2013-04-07 16:14:24   1
# 6      FK  K          Y          2013-04-11 11:15:00  2013-04-11 13:06:24   1
# 7      XR  Q          Y          2013-04-14 11:05:00  2013-04-14 17:10:56   2
# 8      WS  Y          Y          2013-04-16 15:45:00  2013-04-16 17:15:29   2
# 9      EQ  Y          Y          2013-04-18 08:00:00  2013-04-18 08:53:56   2
#
#    year month  oid
# 0  2013     3  NULL
# 1  2013     3  NULL
# 2  2013     3  NULL
# 3  2013     3  SYDA82546
# 4  2013     3  SYDA82546
# 5  2013     3  NULL
# 6  2013     3  NULL
# 7  2013     3  NULL
# 8  2013     3  NULL
# 9  2013     3  NULL
#
# [10 rows x 38 columns]

# %%
bookings_small.columns
# Out:
# Index(['act_date           ', 'source', 'pos_ctry', 'pos_iata', 'pos_oid  ',
#        'rloc          ', 'cre_date           ', 'duration', 'distance',
#        'dep_port', 'dep_city', 'dep_ctry', 'arr_port', 'arr_city', 'arr_ctry',
#        'lst_port', 'lst_city', 'lst_ctry', 'brd_port', 'brd_city', 'brd_ctry',
#        'off_port', 'off_city', 'off_ctry', 'mkt_port', 'mkt_city', 'mkt_ctry',
#        'intl', 'route          ', 'carrier', 'bkg_class', 'cab_class',
#        'brd_time           ', 'off_time           ', 'pax', 'year', 'month',
#        'oid      '],
#       dtype='object')

# %%
len(bookings_small.index)
# Out:
# 10

# %%
fields = ['arr_port','pax']
# %time bookings = pd.read_csv(bookingPath, header=0, sep='^', usecols=fields)
len(bookings.index)
# Out:
# CPU times: user 19.8 s, sys: 1.39 s, total: 21.2 s
# Wall time: 27 s
# 10000010

# %%
searchesPath = '../../searches.csv'
fields = ['Destination', 'Date']
# %time searches = pd.read_csv(searchesPath, header=0, sep='^', usecols=fields)
len(searches.index)
# Out:
# CPU times: user 23 s, sys: 1.48 s, total: 24.4 s
# Wall time: 30 s
# 20390198

# %% [markdown]
# **Solution to Question 1**
# Number of lines of bookings file: 10000010
# Number of lines of searches file: 20390198

# %% [markdown]
# ########################################################

# %% [markdown]
# **Question 2**
#
# The arrival airport is the column arr_port. It is the IATA code for the airport.
#
# To get the total number of passengers for an airport, you can sum the column pax, grouping by arr_port. Note that there is negative pax. That corresponds to cancelations. So to get the total number of passengers that have actually booked, you should sum including the negatives (that will remove the canceled bookings).
#
# Print the top 10 arrival airports in the standard output, including the number of passengers.
#
# Required: Get the name of the city or airport corresponding to that airport (programmatically, we suggest to have a look at GeoBases in Github)
#
# If you’re using Python, can you solve this problem using pandas?

# %%
bookings.columns = bookings.columns.str.strip()

# %%
preGrouped = bookings.groupby(['arr_port'])['pax'].sum()

# %%
type(preGrouped)
# Out:
# pandas.core.series.Series

# %%
grouped = pd.DataFrame({'arr_port':preGrouped.index, 'acc_pax':preGrouped.values})

# %%
grouped
# Out:
#       arr_port  acc_pax
# 0     AAB          30.0
# 1     AAE         810.0
# 2     AAL         810.0
# 3     AAN          20.0
# 4     AAQ        1650.0
# 5     AAR         500.0
# 6     ABA          90.0
# 7     ABB          40.0
# 8     ABE         880.0
# 9     ABI         150.0
# 10    ABJ        2600.0
# 11    ABK           0.0
# 12    ABQ        4290.0
# 13    ABR           0.0
# 14    ABS         310.0
# 15    ABT         300.0
# 16    ABV        1950.0
# 17    ABX         300.0
# 18    ABY          90.0
# 19    ABZ        3710.0
# 20    ACA         700.0
# 21    ACC        3810.0
# 22    ACE        1700.0
# 23    ACH          20.0
# 24    ACI          40.0
# 25    ACK         200.0
# 26    ACT         180.0
# 27    ACV         140.0
# 28    ACY         190.0
# 29    ADA         980.0
# ...        ...      ...
# 2245  ZAZ          50.0
# 2246  ZBF         110.0
# 2247  ZBL          90.0
# 2248  ZCL         150.0
# 2249  ZCO         490.0
# 2250  ZDH          60.0
# 2251  ZFQ          40.0
# 2252  ZFV         120.0
# 2253  ZHA           0.0
# 2254  ZIG          40.0
# 2255  ZIH         870.0
# 2256  ZLN           0.0
# 2257  ZLO         500.0
# 2258  ZNE        1510.0
# 2259  ZNZ         970.0
# 2260  ZOS          70.0
# 2261  ZQN        1720.0
# 2262  ZRH       20190.0
# 2263  ZSA          10.0
# 2264  ZSE          10.0
# 2265  ZTH          50.0
# 2266  ZUH          40.0
# 2267  ZVE          40.0
# 2268  ZVJ          20.0
# 2269  ZVK          20.0
# 2270  ZWE          30.0
# 2271  ZWS         620.0
# 2272  ZYL        1290.0
# 2273  ZYN          20.0
# 2274  ZYR        1020.0
#
# [2275 rows x 2 columns]

# %%
geo = pd.read_csv('../data/geobase/airports_geonames_only_clean.csv', sep='^', header=None).iloc[:,0:2]

# %%
geo
# Out:
#         0                                     1
# 0     AUH       Abu Dhabi International Airport
# 1     AZI              Abu Dhabi Bateen Airport
# 2     AAN          Al Ain International Airport
# 3     DXB           Dubai International Airport
# 4     FJR                              Fujairah
# 5     RKT  Ras Al Khaimah International Airport
# 6     SHJ         Sharjah International Airport
# 7     KBL                   Kabul International
# 8     FAH                                 Farah
# 9     FBD                              Faizabad
# 10    HEA                                 Herat
# 11    JAA                             Jalalabad
# 12    MZR                        Mazar-I-Sharif
# 13    ANU      V. C. Bird International Airport
# 14    AXA                    Wall Blake Airport
# 15    TIA                          Tirane/Rinas
# 16    EVN                             Zvartnots
# 17    LWN                                Shirak
# 18    SXM              Princess Juliana Airport
# 19    EUX     Franklin Delano Roosevelt Airport
# 20    BON                      Flamingo Airport
# 21    CUR         Curacao International Airport
# 22    BUG                     Monbaca Benguela
# 23    CAB                               Cabinda
# 24    NOV                   Huambo Nova Lisboa
# 25    SVP                      Bie Silva Porto
# 26    LAD                                Luanda
# 27    MDQ                         Mar Del Plata
# 28    ROS                 Rosario International
# 29    COC                   Concordia Aerodrome
# ...   ...                                   ...
# 3529  CIP                               Chipata
# 3530  KMZ                                 Kaoma
# 3531  KAA                                Kasama
# 3532  QKE                                 Kabwe
# 3533  LVI                           Livingstone
# 3534  LUN           Lusaka Internationalairport
# 3535  MNS                                 Mansa
# 3536  MFU                                 Mfuwe
# 3537  MNR                                 Mongu
# 3538  NLA                                 Ndola
# 3539  SXG                               Senanga
# 3540  SJQ                               Sesheke
# 3541  SLI                               Solwezi
# 3542  BBZ                               Zambezi
# 3543  KIW                            Southdowns
# 3544  BUQ                      Bulawayo Airport
# 3545  HRE          Harare International Airport
# 3546  CHJ                              Chipinge
# 3547  BFO                         Buffalo Range
# 3548  VFA                        Victoria Falls
# 3549  KAB                                Kariba
# 3550  MVZ                              Masvingo
# 3551  GWE                                 Gweru
# 3552  HWN                  Hwange National Park
# 3553  MPN                Mount Pleasant Airport
# 3554  OHD                                 Ohrid
# 3555  SKP                       Skopje-Petrovec
# 3556  PSY                       Stanley Airport
# 3557  TIH                         Tikehau Atoll
# 3558  MOZ                                 Temae
#
# [3559 rows x 2 columns]

# %%
geo.columns = ['arr_port', 'airport']

# %%
merged = pd.merge(grouped, geo, on=['arr_port'])

# %%
merged
# Out:
# Empty DataFrame
# Columns: [arr_port, acc_pax, airport]
# Index: []

# %%
grouped
# Out:
#       arr_port  acc_pax
# 0     AAB          30.0
# 1     AAE         810.0
# 2     AAL         810.0
# 3     AAN          20.0
# 4     AAQ        1650.0
# 5     AAR         500.0
# 6     ABA          90.0
# 7     ABB          40.0
# 8     ABE         880.0
# 9     ABI         150.0
# 10    ABJ        2600.0
# 11    ABK           0.0
# 12    ABQ        4290.0
# 13    ABR           0.0
# 14    ABS         310.0
# 15    ABT         300.0
# 16    ABV        1950.0
# 17    ABX         300.0
# 18    ABY          90.0
# 19    ABZ        3710.0
# 20    ACA         700.0
# 21    ACC        3810.0
# 22    ACE        1700.0
# 23    ACH          20.0
# 24    ACI          40.0
# 25    ACK         200.0
# 26    ACT         180.0
# 27    ACV         140.0
# 28    ACY         190.0
# 29    ADA         980.0
# ...        ...      ...
# 2245  ZAZ          50.0
# 2246  ZBF         110.0
# 2247  ZBL          90.0
# 2248  ZCL         150.0
# 2249  ZCO         490.0
# 2250  ZDH          60.0
# 2251  ZFQ          40.0
# 2252  ZFV         120.0
# 2253  ZHA           0.0
# 2254  ZIG          40.0
# 2255  ZIH         870.0
# 2256  ZLN           0.0
# 2257  ZLO         500.0
# 2258  ZNE        1510.0
# 2259  ZNZ         970.0
# 2260  ZOS          70.0
# 2261  ZQN        1720.0
# 2262  ZRH       20190.0
# 2263  ZSA          10.0
# 2264  ZSE          10.0
# 2265  ZTH          50.0
# 2266  ZUH          40.0
# 2267  ZVE          40.0
# 2268  ZVJ          20.0
# 2269  ZVK          20.0
# 2270  ZWE          30.0
# 2271  ZWS         620.0
# 2272  ZYL        1290.0
# 2273  ZYN          20.0
# 2274  ZYR        1020.0
#
# [2275 rows x 2 columns]

# %%
geo
# Out:
#      arr_port                               airport
# 0         AUH       Abu Dhabi International Airport
# 1         AZI              Abu Dhabi Bateen Airport
# 2         AAN          Al Ain International Airport
# 3         DXB           Dubai International Airport
# 4         FJR                              Fujairah
# 5         RKT  Ras Al Khaimah International Airport
# 6         SHJ         Sharjah International Airport
# 7         KBL                   Kabul International
# 8         FAH                                 Farah
# 9         FBD                              Faizabad
# 10        HEA                                 Herat
# 11        JAA                             Jalalabad
# 12        MZR                        Mazar-I-Sharif
# 13        ANU      V. C. Bird International Airport
# 14        AXA                    Wall Blake Airport
# 15        TIA                          Tirane/Rinas
# 16        EVN                             Zvartnots
# 17        LWN                                Shirak
# 18        SXM              Princess Juliana Airport
# 19        EUX     Franklin Delano Roosevelt Airport
# 20        BON                      Flamingo Airport
# 21        CUR         Curacao International Airport
# 22        BUG                     Monbaca Benguela
# 23        CAB                               Cabinda
# 24        NOV                   Huambo Nova Lisboa
# 25        SVP                      Bie Silva Porto
# 26        LAD                                Luanda
# 27        MDQ                         Mar Del Plata
# 28        ROS                 Rosario International
# 29        COC                   Concordia Aerodrome
# ...       ...                                   ...
# 3529      CIP                               Chipata
# 3530      KMZ                                 Kaoma
# 3531      KAA                                Kasama
# 3532      QKE                                 Kabwe
# 3533      LVI                           Livingstone
# 3534      LUN           Lusaka Internationalairport
# 3535      MNS                                 Mansa
# 3536      MFU                                 Mfuwe
# 3537      MNR                                 Mongu
# 3538      NLA                                 Ndola
# 3539      SXG                               Senanga
# 3540      SJQ                               Sesheke
# 3541      SLI                               Solwezi
# 3542      BBZ                               Zambezi
# 3543      KIW                            Southdowns
# 3544      BUQ                      Bulawayo Airport
# 3545      HRE          Harare International Airport
# 3546      CHJ                              Chipinge
# 3547      BFO                         Buffalo Range
# 3548      VFA                        Victoria Falls
# 3549      KAB                                Kariba
# 3550      MVZ                              Masvingo
# 3551      GWE                                 Gweru
# 3552      HWN                  Hwange National Park
# 3553      MPN                Mount Pleasant Airport
# 3554      OHD                                 Ohrid
# 3555      SKP                       Skopje-Petrovec
# 3556      PSY                       Stanley Airport
# 3557      TIH                         Tikehau Atoll
# 3558      MOZ                                 Temae
#
# [3559 rows x 2 columns]

# %%
merged = pd.merge(grouped, geo, on=['arr_port'])
merged
# Out:
# Empty DataFrame
# Columns: [arr_port, acc_pax, airport]
# Index: []

# %%
grouped['arr_port'] = grouped['arr_port'].str.strip()

# %%
merged = pd.merge(grouped, geo, on=['arr_port'])
merged
# Out:
#      arr_port  acc_pax                                            airport
# 0         AAE    810.0                                             Annaba
# 1         AAL    810.0                                             Alborg
# 2         AAN     20.0                       Al Ain International Airport
# 3         AAQ   1650.0                                  Anapa / Vitiazevo
# 4         AAR    500.0                                           Tirstrup
# 5         ABA     90.0                                             Abakan
# 6         ABE    880.0                                     Martin Airport
# 7         ABI    150.0                           Abilene Regional Airport
# 8         ABJ   2600.0                                            Abidjan
# 9         ABK      0.0                               Kabre Dare Military
# 10        ABQ   4290.0                  Albuquerque International Airport
# 11        ABR      0.0                          Aberdeen Regional Airport
# 12        ABS    310.0                                         Abu Simbel
# 13        ABT    300.0                                            Al Baha
# 14        ABX    300.0                                     Albury Airport
# 15        ABY     90.0                 Southwest Georgia Regional Airport
# 16        ABZ   3710.0                                    Aberdeen / Dyce
# 17        ACA    700.0                              Acapulco / G. Alvarez
# 18        ACC   3810.0                       Kotoka International Airport
# 19        ACE   1700.0                             Lanzarote / Aeropuerto
# 20        ACH     20.0                            Saint Gallen-Altenrhein
# 21        ACI     40.0                          Alderney / Channel Island
# 22        ACK    200.0                         Nantucket Memorial Airport
# 23        ACT    180.0                              Waco Regional Airport
# 24        ACV    140.0                                     Arcata Airport
# 25        ACY    190.0                Atlantic City International Airport
# 26        ADA    980.0                                  Adana / Sakirpasa
# 27        ADB   3060.0                             Izmir / Adnan Menderes
# 28        ADD   5880.0                                        Addis Ababa
# 29        ADE    600.0                                               Aden
# ...       ...      ...                                                ...
# 1665      YNT    430.0                                            Laishan
# 1666      YOW   3860.0                                 Ottawa Int'L. Ont.
# 1667      YQB   1580.0                  Jean Lesage International Airport
# 1668      YQR   1400.0                                             Regina
# 1669      YUL  14040.0  Montreal / Pierre Elliot Trudeau International...
# 1670      YUM    410.0                         Yuma International Airport
# 1671      YVR  15920.0            Vancouver International Airport;  B. C.
# 1672      YWG   2680.0                          Winnipeg Int. Airportman.
# 1673      YXH     30.0                               Medicine Hat;  Alta.
# 1674      YXU    450.0                                      London;  Ont.
# 1675      YYC   9810.0                      Calgary International;  Alta.
# 1676      YYJ   1290.0                      Victoria Int. Airport;  B. C.
# 1677      YYZ  26070.0                        Toronto Pearson Int'L. Ont.
# 1678      ZAD     90.0                                              Zadar
# 1679      ZAG   3610.0                                     Zagreb / Pleso
# 1680      ZAL     90.0                                           Valdivia
# 1681      ZAM     80.0                                          Zamboanga
# 1682      ZCL    150.0                                  Zacatecas Airport
# 1683      ZCO    490.0                                             Temuco
# 1684      ZHA      0.0                                          Zhanjiang
# 1685      ZIG     40.0                                         Ziguinchor
# 1686      ZIH    870.0                                 Ixtapa-Zihuatanejo
# 1687      ZLO    500.0                          Manzanillo International
# 1688      ZNZ    970.0                                 Zanzibar / Kisauni
# 1689      ZQN   1720.0                                 Queenstown Airport
# 1690      ZRH  20190.0                                      Zurich-Kloten
# 1691      ZSE     10.0                         Saint-Pierre - Pierrefonds
# 1692      ZTH     50.0                                 Zakinthos Airport
# 1693      ZVK     20.0                                        Savannakhet
# 1694      ZYL   1290.0                                             Sylhet
#
# [1695 rows x 3 columns]

# %%
merged.sort_values(by=['acc_pax'], ascending=False).head(10)
# Out:
#      arr_port  acc_pax                               airport
# 883       LHR  88809.0               London Heathrow Airport
# 960       MCO  70930.0         Orlando International Airport
# 853       LAX  70530.0     Los Angeles International Airport
# 851       LAS  69630.0        McCarran International Airport
# 728       JFK  66270.0  John F Kennedy International Airport
# 272       CDG  64490.0             Paris - Charles-de-Gaulle
# 190       BKK  59460.0                          Suvarnabhumi
# 990       MIA  58150.0           Miami International Airport
# 1357      SFO  58000.0   San Francisco International Airport
# 438       DXB  55590.0           Dubai International Airport

# %% [markdown]
# **Solution to question 2**
# See above

# %% [markdown]
# ########################################################

# %% [markdown]
# **Question 3**
#
# Plot the monthly number of searches for flights arriving at Malaga, Madrid or Barcelona
#
# For the arriving airport, you can use the Destination column in the searches file. Plot a curve for Malaga, another one for Madrid, and another one for Barcelona, in the same figure.
#
# If you’re using Python, can you solve this problem using pandas?

# %%
sg = pd.merge(searches, geo, how='left', left_on=['Destination'], right_on=['arr_port'])

# %%
sg
# Out:
#                 Date Destination arr_port  \
# 0         2013-01-01         AUH      AUH
# 1         2013-01-01         MIL      NaN
# 2         2013-01-01         SFO      SFO
# 3         2013-01-01         ARN      ARN
# 4         2013-01-01         MAD      MAD
# 5         2013-01-01         BLR      BLR
# 6         2013-01-01         PAR      NaN
# 7         2013-01-01         DUB      DUB
# 8         2013-01-01         ACE      ACE
# 9         2013-01-01         BGW      NaN
# 10        2013-01-01         BUD      BUD
# 11        2013-01-01         POA      POA
# 12        2013-01-01         MXP      MXP
# 13        2013-01-01         LON      NaN
# 14        2013-01-01         SNN      SNN
# 15        2013-01-01         SLZ      SLZ
# 16        2013-01-01         PHL      PHL
# 17        2013-01-01         GRU      GRU
# 18        2013-01-01         IKT      IKT
# 19        2013-01-01         HKG      HKG
# 20        2013-01-01         SEA      SEA
# 21        2013-01-01         STN      STN
# 22        2013-01-01         FUE      FUE
# 23        2013-01-01         IST      IST
# 24        2013-01-01         VIE      VIE
# 25        2013-01-01         SAO      SAO
# 26        2013-01-01         BRI      BRI
# 27        2013-01-01         JED      JED
# 28        2013-01-01         CPH      CPH
# 29        2013-01-01         DRS      DRS
# ...              ...         ...      ...
# 20390168  2013-10-13         ZAD      ZAD
# 20390169  2013-10-13         PEI      PEI
# 20390170  2013-10-13         MLE      MLE
# 20390171  2013-10-13         DEL      DEL
# 20390172  2013-10-13         ABJ      ABJ
# 20390173  2013-10-13         BRU      BRU
# 20390174  2013-10-13         CDG      CDG
# 20390175  2013-10-13         BKK      BKK
# 20390176  2013-10-13         SSA      SSA
# 20390177  2013-10-13         CPH      CPH
# 20390178  2013-10-13         CGH      CGH
# 20390179  2013-10-13         PVR      PVR
# 20390180  2013-10-13         HAM      HAM
# 20390181  2013-10-13         PRG      PRG
# 20390182  2013-10-13         JFK      JFK
# 20390183  2013-10-13         ICN      ICN
# 20390184  2013-10-13         PMI      PMI
# 20390185  2013-10-13         BKK      BKK
# 20390186  2013-10-13         AMS      AMS
# 20390187  2013-10-13         SRP      SRP
# 20390188  2013-10-13         MCT      MCT
# 20390189  2013-10-13         SKG      SKG
# 20390190  2013-10-13         AMD      AMD
# 20390191  2013-10-13         BRS      BRS
# 20390192  2013-10-13         AKL      AKL
# 20390193  2013-10-13         NBO      NBO
# 20390194  2013-10-13         ALA      ALA
# 20390195  2013-10-13         LHR      LHR
# 20390196  2013-10-13         MAD      MAD
# 20390197  2013-10-13          HA      NaN
#
#                                                     airport
# 0                           Abu Dhabi International Airport
# 1                                                       NaN
# 2                       San Francisco International Airport
# 3                                                   Arlanda
# 4                                          Madrid / Barajas
# 5                                     Bangalore / Hindustan
# 6                                                       NaN
# 7                                            Dublin Airport
# 8                                    Lanzarote / Aeropuerto
# 9                                                       NaN
# 10                                      Budapest / Ferihegy
# 11                    Aeroporto Internacional Salgado Filho
# 12                                 Aeroporto della Malpensa
# 13                                                      NaN
# 14                                          Shannon Airport
# 15                                      Sao Luiz Aeroporto
# 16                       Philadelphia International Airport
# 17                                        Guarulhos Airport
# 18                                                  Irkutsk
# 19                          Hong Kong International Airport
# 20                     Seattle-Tacoma International Airport
# 21                                         Stansted Airport
# 22                               Fuerteventura / Aeropuerto
# 23                                       Istanbul / Ataturk
# 24                                 Flughafen Wien-Schwechat
# 25                                         Marte Civ / Mil
# 26                                    Bari / Palese Macchie
# 27            Jeddah King Abdul Aziz International Airport
# 28                                                  Kastrup
# 29                                                  Dresden
# ...                                                     ...
# 20390168                                              Zadar
# 20390169                                 Pereira / Matecana
# 20390170                                               Male
# 20390171                                  New Delhi / Palam
# 20390172                                            Abidjan
# 20390173                                 Bruxelles National
# 20390174                          Paris - Charles-de-Gaulle
# 20390175                                       Suvarnabhumi
# 20390176                                Salvador Aeroporto
# 20390177                                            Kastrup
# 20390178                      Sao Paulo/Congonhas Aeroporto
# 20390179       Licenciado Gustaavo Diaz Ordaz International
# 20390180                                            Hamburg
# 20390181                                     Praha - Ruzyne
# 20390182               John F Kennedy International Airport
# 20390183                      Incheon International Airport
# 20390184                   Palma de Mallorca / Son San Juan
# 20390185                                       Suvarnabhumi
# 20390186                         Amsterdam Airport Schiphol
# 20390187                                Stord / Soerstokken
# 20390188                             Matar as Sib ad Duwali
# 20390189                              Thessaloniki Airport
# 20390190                                          Ahmadabad
# 20390191                                Bristol / Lulsgate
# 20390192                     Auckland International Airport
# 20390193  Nairobi/Jomo Kenyatta Airport TWR/APP/NOF/Civi...
# 20390194                                             Almaty
# 20390195                            London Heathrow Airport
# 20390196                                   Madrid / Barajas
# 20390197                                                NaN
#
# [20390198 rows x 4 columns]

# %%
df = sg.loc[sg['airport'].str.contains('Madrid')==True]

# %%
df
# Out:
#                 Date Destination arr_port           airport
# 4         2013-01-01         MAD      MAD  Madrid / Barajas
# 151       2013-01-01         MAD      MAD  Madrid / Barajas
# 375       2013-01-01         MAD      MAD  Madrid / Barajas
# 406       2013-01-01         MAD      MAD  Madrid / Barajas
# 509       2013-01-01         MAD      MAD  Madrid / Barajas
# 606       2013-01-01         MAD      MAD  Madrid / Barajas
# 688       2013-01-01         MAD      MAD  Madrid / Barajas
# 791       2013-01-01         MAD      MAD  Madrid / Barajas
# 798       2013-01-01         MAD      MAD  Madrid / Barajas
# 895       2013-01-01         MAD      MAD  Madrid / Barajas
# 897       2013-01-01         MAD      MAD  Madrid / Barajas
# 1026      2013-01-02         MAD      MAD  Madrid / Barajas
# 1038      2013-01-02         MAD      MAD  Madrid / Barajas
# 1061      2013-01-02         MAD      MAD  Madrid / Barajas
# 1117      2013-01-02         MAD      MAD  Madrid / Barajas
# 1233      2013-01-02         MAD      MAD  Madrid / Barajas
# 1407      2013-01-02         MAD      MAD  Madrid / Barajas
# 1584      2013-01-02         MAD      MAD  Madrid / Barajas
# 1619      2013-01-02         MAD      MAD  Madrid / Barajas
# 1700      2013-01-02         MAD      MAD  Madrid / Barajas
# 1715      2013-01-02         MAD      MAD  Madrid / Barajas
# 1790      2013-01-02         MAD      MAD  Madrid / Barajas
# 2162      2013-01-03         MAD      MAD  Madrid / Barajas
# 2280      2013-01-03         MAD      MAD  Madrid / Barajas
# 2813      2013-01-03         MAD      MAD  Madrid / Barajas
# 2856      2013-01-03         MAD      MAD  Madrid / Barajas
# 2963      2013-01-03         MAD      MAD  Madrid / Barajas
# 3077      2013-01-04         MAD      MAD  Madrid / Barajas
# 3113      2013-01-04         MAD      MAD  Madrid / Barajas
# 3118      2013-01-04         MAD      MAD  Madrid / Barajas
# ...              ...         ...      ...               ...
# 20387892  2013-10-11         MAD      MAD  Madrid / Barajas
# 20387905  2013-10-11         MAD      MAD  Madrid / Barajas
# 20387947  2013-10-11         MAD      MAD  Madrid / Barajas
# 20387992  2013-10-11         MAD      MAD  Madrid / Barajas
# 20388011  2013-10-11         MAD      MAD  Madrid / Barajas
# 20388224  2013-10-11         MAD      MAD  Madrid / Barajas
# 20388230  2013-10-11         MAD      MAD  Madrid / Barajas
# 20388253  2013-10-11         MAD      MAD  Madrid / Barajas
# 20388305  2013-10-11         MAD      MAD  Madrid / Barajas
# 20388371  2013-10-12         MAD      MAD  Madrid / Barajas
# 20388383  2013-10-12         MAD      MAD  Madrid / Barajas
# 20388536  2013-10-12         MAD      MAD  Madrid / Barajas
# 20388553  2013-10-12         MAD      MAD  Madrid / Barajas
# 20388579  2013-10-12         MAD      MAD  Madrid / Barajas
# 20388662  2013-10-12         MAD      MAD  Madrid / Barajas
# 20388758  2013-10-12         MAD      MAD  Madrid / Barajas
# 20388921  2013-10-12         MAD      MAD  Madrid / Barajas
# 20389019  2013-10-12         MAD      MAD  Madrid / Barajas
# 20389080  2013-10-12         MAD      MAD  Madrid / Barajas
# 20389086  2013-10-12         MAD      MAD  Madrid / Barajas
# 20389089  2013-10-12         MAD      MAD  Madrid / Barajas
# 20389101  2013-10-12         MAD      MAD  Madrid / Barajas
# 20389160  2013-10-12         MAD      MAD  Madrid / Barajas
# 20389206  2013-10-12         MAD      MAD  Madrid / Barajas
# 20389555  2013-10-13         MAD      MAD  Madrid / Barajas
# 20389748  2013-10-13         MAD      MAD  Madrid / Barajas
# 20389834  2013-10-13         MAD      MAD  Madrid / Barajas
# 20390045  2013-10-13         MAD      MAD  Madrid / Barajas
# 20390160  2013-10-13         MAD      MAD  Madrid / Barajas
# 20390196  2013-10-13         MAD      MAD  Madrid / Barajas
#
# [269143 rows x 4 columns]

# %%
df["Date"] = pd.to_datetime(df["Date"])
# Out:
# /home/glin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df = df.copy(deep=True)

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df['Date']
# Out:
# 4          2013-01-01
# 151        2013-01-01
# 375        2013-01-01
# 406        2013-01-01
# 509        2013-01-01
# 606        2013-01-01
# 688        2013-01-01
# 791        2013-01-01
# 798        2013-01-01
# 895        2013-01-01
# 897        2013-01-01
# 1026       2013-01-02
# 1038       2013-01-02
# 1061       2013-01-02
# 1117       2013-01-02
# 1233       2013-01-02
# 1407       2013-01-02
# 1584       2013-01-02
# 1619       2013-01-02
# 1700       2013-01-02
# 1715       2013-01-02
# 1790       2013-01-02
# 2162       2013-01-03
# 2280       2013-01-03
# 2813       2013-01-03
# 2856       2013-01-03
# 2963       2013-01-03
# 3077       2013-01-04
# 3113       2013-01-04
# 3118       2013-01-04
#               ...
# 20387892   2013-10-11
# 20387905   2013-10-11
# 20387947   2013-10-11
# 20387992   2013-10-11
# 20388011   2013-10-11
# 20388224   2013-10-11
# 20388230   2013-10-11
# 20388253   2013-10-11
# 20388305   2013-10-11
# 20388371   2013-10-12
# 20388383   2013-10-12
# 20388536   2013-10-12
# 20388553   2013-10-12
# 20388579   2013-10-12
# 20388662   2013-10-12
# 20388758   2013-10-12
# 20388921   2013-10-12
# 20389019   2013-10-12
# 20389080   2013-10-12
# 20389086   2013-10-12
# 20389089   2013-10-12
# 20389101   2013-10-12
# 20389160   2013-10-12
# 20389206   2013-10-12
# 20389555   2013-10-13
# 20389748   2013-10-13
# 20389834   2013-10-13
# 20390045   2013-10-13
# 20390160   2013-10-13
# 20390196   2013-10-13
# Name: Date, Length: 269143, dtype: datetime64[ns]

# %%
per = df.Date.dt.to_period("M")

# %%
per
# Out:
# 4           2013-01
# 151         2013-01
# 375         2013-01
# 406         2013-01
# 509         2013-01
# 606         2013-01
# 688         2013-01
# 791         2013-01
# 798         2013-01
# 895         2013-01
# 897         2013-01
# 1026        2013-01
# 1038        2013-01
# 1061        2013-01
# 1117        2013-01
# 1233        2013-01
# 1407        2013-01
# 1584        2013-01
# 1619        2013-01
# 1700        2013-01
# 1715        2013-01
# 1790        2013-01
# 2162        2013-01
# 2280        2013-01
# 2813        2013-01
# 2856        2013-01
# 2963        2013-01
# 3077        2013-01
# 3113        2013-01
# 3118        2013-01
#              ...
# 20387892    2013-10
# 20387905    2013-10
# 20387947    2013-10
# 20387992    2013-10
# 20388011    2013-10
# 20388224    2013-10
# 20388230    2013-10
# 20388253    2013-10
# 20388305    2013-10
# 20388371    2013-10
# 20388383    2013-10
# 20388536    2013-10
# 20388553    2013-10
# 20388579    2013-10
# 20388662    2013-10
# 20388758    2013-10
# 20388921    2013-10
# 20389019    2013-10
# 20389080    2013-10
# 20389086    2013-10
# 20389089    2013-10
# 20389101    2013-10
# 20389160    2013-10
# 20389206    2013-10
# 20389555    2013-10
# 20389748    2013-10
# 20389834    2013-10
# 20390045    2013-10
# 20390160    2013-10
# 20390196    2013-10
# Name: Date, Length: 269143, dtype: period[M]

# %%
monthly = df.groupby(per).count()

# %%
monthly
# Out:
#           Date  Destination  arr_port  airport
# Date
# 2013-01  24258        24258     24258    24258
# 2013-02  22800        22800     22800    22800
# 2013-03  24681        24681     24681    24681
# 2013-04  25251        25251     25251    25251
# 2013-05  26334        26334     26334    26334
# 2013-06  22800        22800     22800    22800
# 2013-07  22971        22971     22971    22971
# 2013-08  21831        21831     21831    21831
# 2013-09  21147        21147     21147    21147
# 2013-10  22294        22294     22294    22294
# 2013-11  20272        20272     20272    20272
# 2013-12  14504        14504     14504    14504

# %%
monthly['Date'].plot

# %%
import matplotlib.pyplot as plt

# %%
monthly['Date'].plot

# %%
plt.show()

# %%
plt.title('Monthly searches')
# Out:
# Text(0.5,1,'Monthly searches')

# %%
monthly['Date'].plot

# %%
plt.show()

# %%
plt.xlabel('Month')
plt.ylabel('Number of searches')
plt.savefig('monthly_searches_nb')

# %%
monthly['Date']
# Out:
# Date
# 2013-01    24258
# 2013-02    22800
# 2013-03    24681
# 2013-04    25251
# 2013-05    26334
# 2013-06    22800
# 2013-07    22971
# 2013-08    21831
# 2013-09    21147
# 2013-10    22294
# 2013-11    20272
# 2013-12    14504
# Freq: M, Name: Date, dtype: int64

# %%
monthly['Date'].plot()

# %%
def monthlyAgg(airport):
    df = sg.loc[sg['airport'].str.contains(airport)==True]
    df = df.copy(deep=True)
    df["Date"] = pd.to_datetime(df["Date"])
    per = df.Date.dt.to_period("M")
    monthly = df.groupby(per).count()
    return monthly['Date']

# %%
monthly_agp = monthlyAgg('Malaga')
monthly_mad = monthlyAgg('Madrid')
monthly_bcn = monthlyAgg('Barcelona')

# %%
plt.title('Monthly searches for Malaga, Madrid and Barcelona')
monthly_agp.plot(color="green", label='Malaga')
monthly_mad.plot(color="red", label='Madrid')
monthly_bcn.plot(color="blue", label='Barcelona')

# %%
plt.xlabel('Month')
plt.ylabel('Number of searches')
plt.savefig('monthly_searches_nb')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.title('Monthly searches for Malaga, Madrid and Barcelona')
monthly_agp.plot(color="green", label='Malaga')
monthly_mad.plot(color="red", label='Madrid')
monthly_bcn.plot(color="blue", label='Barcelona')
plt.xlabel('Month in 2013')
plt.ylabel('Number of searches')
plt.savefig('monthly_searches_nb')
plt.legend()
plt.show()

# %%
plt.title('Monthly searches for Malaga, Madrid and Barcelona')
monthly_agp.plot(color="green", label='Malaga')
monthly_mad.plot(color="red", label='Madrid')
monthly_bcn.plot(color="blue", label='Barcelona')
plt.xlabel('Month in 2013')
plt.ylabel('Number of searches')
plt.legend()
plt.savefig('monthly_searches_nb')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1dd2cb201fd4> in <module>()
# ----> 1 plt.title('Monthly searches for Malaga, Madrid and Barcelona')
#       2 monthly_agp.plot(color="green", label='Malaga')
#       3 monthly_mad.plot(color="red", label='Madrid')
#       4 monthly_bcn.plot(color="blue", label='Barcelona')
#       5 plt.xlabel('Month in 2013')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# **Solution to question 3** See above

# %% [markdown]
# ###############################################################

# %% [markdown]
# **Question 4**
#
# Match searches with bookings.
#
# For every search in the searches file, find out whether the search ended up in a booking or not (using the info in the bookings file). For instance, search and booking origin and destination should match. For the bookings file, origin and destination are the columns dep_port and arr_port, respectively. Generate a CSV file with the search data, and an additional field, containing 1 if the search ended up in a booking, and 0 otherwise.
#
# If you’re using Python, can you solve this problem using pandas?

# %%
bookingsPath = '../../bookings.csv'
bookings = pd.read_csv(bookingsPath, header=0, sep='^', usecols = ['brd_time           ','dep_port','arr_port'])

# %%
searchesPath = '../../searches.csv'
searches = pd.read_csv(searchesPath, header=0, sep='^', usecols = ['Seg1Date','Origin','Destination'])

# %%
bookings.columns = bookings.columns.str.strip()

# %%
bookings['brd_time'] = bookings['brd_time'].str.slice(0, 9)
bookings['brd_time']
# Out:
# 0           2013-03-0
# 1           2013-04-1
# 2           2013-07-1
# 3           2013-04-2
# 4           2013-05-1
# 5           2013-04-0
# 6           2013-04-1
# 7           2013-04-1
# 8           2013-04-1
# 9           2013-04-1
# 10          2013-04-1
# 11          2013-04-1
# 12          2013-04-1
# 13          2013-04-1
# 14          2013-04-1
# 15          2013-04-1
# 16          2013-04-1
# 17          2013-04-1
# 18          2013-04-1
# 19          2013-04-0
# 20          2013-05-2
# 21          2013-05-2
# 22          2013-03-2
# 23          2013-08-0
# 24          2013-08-0
# 25          2013-08-2
# 26          2013-03-2
# 27          2013-03-2
# 28          2013-03-2
# 29          2013-03-2
#               ...
# 9999980     2013-06-0
# 9999981     2013-05-0
# 9999982     2013-10-1
# 9999983     2013-10-1
# 9999984     2013-05-1
# 9999985     2013-05-2
# 9999986     2013-06-3
# 9999987     2013-07-2
# 9999988     2013-05-0
# 9999989     2013-05-1
# 9999990     2013-05-3
# 9999991     2013-08-1
# 9999992     2013-05-1
# 9999993     2013-05-1
# 9999994     2013-05-1
# 9999995     2013-08-1
# 9999996     2013-09-1
# 9999997     2013-08-1
# 9999998     2013-09-1
# 9999999     2013-07-0
# 10000000    2013-07-1
# 10000001    2013-11-0
# 10000002    2013-11-0
# 10000003    2013-05-1
# 10000004    2013-05-2
# 10000005    2013-05-2
# 10000006    2013-05-1
# 10000007    2013-07-1
# 10000008    2013-06-0
# 10000009    2013-06-0
# Name: brd_time, Length: 10000010, dtype: object

# %%
bookings_small.columns = bookings_small.columns.str.strip()
bookings_small.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-b8a9ee4a2045> in <module>()
# ----> 1 bookings_small.columns = bookings_small.columns.str.strip()
#       2 bookings_small.columns
#
# NameError: name 'bookings_small' is not defined

# %%
bookingPath_small = '../data/sample/bookings.csv.small'
bookings_small = pd.read_csv(bookingPath_small, header=0, sep='^')

# %%
bookings_small.columns = bookings_small.columns.str.strip()
bookings_small.columns
# Out:
# Index(['act_date', 'source', 'pos_ctry', 'pos_iata', 'pos_oid', 'rloc',
#        'cre_date', 'duration', 'distance', 'dep_port', 'dep_city', 'dep_ctry',
#        'arr_port', 'arr_city', 'arr_ctry', 'lst_port', 'lst_city', 'lst_ctry',
#        'brd_port', 'brd_city', 'brd_ctry', 'off_port', 'off_city', 'off_ctry',
#        'mkt_port', 'mkt_city', 'mkt_ctry', 'intl', 'route', 'carrier',
#        'bkg_class', 'cab_class', 'brd_time', 'off_time', 'pax', 'year',
#        'month', 'oid'],
#       dtype='object')

# %%
searchesPath_small = '../data/sample/searches.csv.small'
searches_small = pd.read_csv(searchesPath_small, header=0, sep='^')

# %%
searches_small.columns
# Out:
# Index(['Date', 'Time', 'TxnCode', 'OfficeID', 'Country', 'Origin',
#        'Destination', 'RoundTrip', 'NbSegments', 'Seg1Departure',
#        'Seg1Arrival', 'Seg1Date', 'Seg1Carrier', 'Seg1BookingCode',
#        'Seg2Departure', 'Seg2Arrival', 'Seg2Date', 'Seg2Carrier',
#        'Seg2BookingCode', 'Seg3Departure', 'Seg3Arrival', 'Seg3Date',
#        'Seg3Carrier', 'Seg3BookingCode', 'Seg4Departure', 'Seg4Arrival',
#        'Seg4Date', 'Seg4Carrier', 'Seg4BookingCode', 'Seg5Departure',
#        'Seg5Arrival', 'Seg5Date', 'Seg5Carrier', 'Seg5BookingCode',
#        'Seg6Departure', 'Seg6Arrival', 'Seg6Date', 'Seg6Carrier',
#        'Seg6BookingCode', 'From', 'IsPublishedForNeg', 'IsFromInternet',
#        'IsFromVista', 'TerminalID', 'InternetOffice'],
#       dtype='object')

# %%
bookings_small['act_date', 'cre_date', 'brd_time', 'off_time', 'dep_port', 'arr_port', 'lst_port', 'brd_port', 'off_port', 'mkt_port']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('act_date', 'cre_date', 'brd_time', 'off_time', 'dep_port', 'arr_port', 'lst_port', 'brd_port', 'off_port', 'mkt_port')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-5917ebecf109> in <module>()
# ----> 1 bookings_small['act_date', 'cre_date', 'brd_time', 'off_time', 'dep_port', 'arr_port', 'lst_port', 'brd_port', 'off_port', 'mkt_port']
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('act_date', 'cre_date', 'brd_time', 'off_time', 'dep_port', 'arr_port', 'lst_port', 'brd_port', 'off_port', 'mkt_port')

# %%
bookings_small['act_date', 'cre_date']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('act_date', 'cre_date')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-2daf51f41b98> in <module>()
# ----> 1 bookings_small['act_date', 'cre_date']
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('act_date', 'cre_date')

# %%
bookings_small[['cre_date', 'act_date', 'brd_time', 'off_time', 'dep_port', 'arr_port', 'lst_port', 'brd_port', 'off_port', 'mkt_port']]
# Out:
#               cre_date             act_date             brd_time  \
# 0  2013-02-22 00:00:00  2013-03-05 00:00:00  2013-03-07 08:50:00
# 1  2013-03-26 00:00:00  2013-03-26 00:00:00  2013-04-12 13:04:00
# 2  2013-03-26 00:00:00  2013-03-26 00:00:00  2013-07-15 07:00:00
# 3  2013-03-26 00:00:00  2013-03-26 00:00:00  2013-04-24 23:59:00
# 4  2013-03-26 00:00:00  2013-03-26 00:00:00  2013-05-14 20:15:00
# 5  2013-03-20 00:00:00  2013-03-20 00:00:00  2013-04-07 10:23:00
# 6  2013-03-20 00:00:00  2013-03-20 00:00:00  2013-04-11 11:15:00
# 7  2013-03-25 00:00:00  2013-03-25 00:00:00  2013-04-14 11:05:00
# 8  2013-03-25 00:00:00  2013-03-25 00:00:00  2013-04-16 15:45:00
# 9  2013-03-25 00:00:00  2013-03-25 00:00:00  2013-04-18 08:00:00
#
#               off_time  dep_port  arr_port  lst_port  brd_port  off_port  \
# 0  2013-03-07 11:33:37  ZRH       LHR       ZRH       LHR       ZRH
# 1  2013-04-12 22:05:40  SAL       CLT       SAL       SAL       CLT
# 2  2013-07-15 11:34:51  SAL       CLT       SAL       CLT       SAL
# 3  2013-04-25 16:06:31  AKL       SVO       AKL       AKL       SVO
# 4  2013-05-16 10:44:50  AKL       SVO       AKL       SVO       AKL
# 5  2013-04-07 16:14:24  DEN       LGA       DEN       DEN       LGA
# 6  2013-04-11 13:06:24  DEN       LGA       DEN       LGA       DEN
# 7  2013-04-14 17:10:56  NRT       SIN       HND       NRT       SIN
# 8  2013-04-16 17:15:29  NRT       SIN       HND       SIN       PEN
# 9  2013-04-18 08:53:56  NRT       SIN       HND       PEN       BKK
#
#    mkt_port
# 0  LHRZRH
# 1  CLTSAL
# 2  CLTSAL
# 3  AKLSVO
# 4  AKLSVO
# 5  DENLGA
# 6  DENLGA
# 7  NRTSIN
# 8  PENSIN
# 9  BKKPEN

# %%
searches_small.columns
# Out:
# Index(['Date', 'Time', 'TxnCode', 'OfficeID', 'Country', 'Origin',
#        'Destination', 'RoundTrip', 'NbSegments', 'Seg1Departure',
#        'Seg1Arrival', 'Seg1Date', 'Seg1Carrier', 'Seg1BookingCode',
#        'Seg2Departure', 'Seg2Arrival', 'Seg2Date', 'Seg2Carrier',
#        'Seg2BookingCode', 'Seg3Departure', 'Seg3Arrival', 'Seg3Date',
#        'Seg3Carrier', 'Seg3BookingCode', 'Seg4Departure', 'Seg4Arrival',
#        'Seg4Date', 'Seg4Carrier', 'Seg4BookingCode', 'Seg5Departure',
#        'Seg5Arrival', 'Seg5Date', 'Seg5Carrier', 'Seg5BookingCode',
#        'Seg6Departure', 'Seg6Arrival', 'Seg6Date', 'Seg6Carrier',
#        'Seg6BookingCode', 'From', 'IsPublishedForNeg', 'IsFromInternet',
#        'IsFromVista', 'TerminalID', 'InternetOffice'],
#       dtype='object')

# %%
searches_small[['Date', 'Origin', 'Destination', 'RoundTrip',
                'Seg1Departure', 'Seg1Arrival', 'Seg1Date',
                'Seg2Departure', 'Seg2Arrival', 'Seg2Date',
                'Seg3Departure', 'Seg3Arrival', 'Seg3Date',
                'Seg4Departure', 'Seg4Arrival', 'Seg4Date',
                'Seg5Departure', 'Seg5Arrival', 'Seg5Date',
                'Seg6Departure', 'Seg6Arrival', 'Seg6Date']]
# Out:
#          Date Origin Destination  RoundTrip Seg1Departure Seg1Arrival  \
# 0  2013-01-01    TXL         AUH          1           TXL         AUH
# 1  2013-01-01    ATH         MIL          0           ATH         MIL
# 2  2013-01-01    ICT         SFO          1           ICT         SFO
# 3  2013-01-01    RNB         ARN          0           RNB         ARN
# 4  2013-01-01    OSL         MAD          1           OSL         MAD
# 5  2013-01-01    IAH         BLR          1           IAH         BLR
# 6  2013-01-01    CPH         PAR          1           CPH         PAR
# 7  2013-01-01    PAR         DUB          1           PAR         DUB
# 8  2013-01-01    DUS         ACE          1           DUS         ACE
# 9  2013-01-01    FRA         BGW          1           FRA         BGW
#
#      Seg1Date Seg2Departure Seg2Arrival    Seg2Date  ...  Seg3Date  \
# 0  2013-01-26           AUH         TXL  2013-02-02  ...       NaN
# 1  2013-01-04           NaN         NaN         NaN  ...       NaN
# 2  2013-08-02           SFO         ICT  2013-08-09  ...       NaN
# 3  2013-01-02           NaN         NaN         NaN  ...       NaN
# 4  2013-03-22           MAD         OSL  2013-03-31  ...       NaN
# 5  2013-02-14           BLR         IAH  2013-02-23  ...       NaN
# 6  2013-03-02           PAR         CPH  2013-03-07  ...       NaN
# 7  2013-02-12           DUB         PAR  2013-02-17  ...       NaN
# 8  2013-03-30           ACE         DUS  2013-04-06  ...       NaN
# 9  2013-02-26           BGW         FRA  2013-04-08  ...       NaN
#
#    Seg4Departure  Seg4Arrival  Seg4Date  Seg5Departure  Seg5Arrival  Seg5Date  \
# 0            NaN          NaN       NaN            NaN          NaN       NaN
# 1            NaN          NaN       NaN            NaN          NaN       NaN
# 2            NaN          NaN       NaN            NaN          NaN       NaN
# 3            NaN          NaN       NaN            NaN          NaN       NaN
# 4            NaN          NaN       NaN            NaN          NaN       NaN
# 5            NaN          NaN       NaN            NaN          NaN       NaN
# 6            NaN          NaN       NaN            NaN          NaN       NaN
# 7            NaN          NaN       NaN            NaN          NaN       NaN
# 8            NaN          NaN       NaN            NaN          NaN       NaN
# 9            NaN          NaN       NaN            NaN          NaN       NaN
#
#    Seg6Departure  Seg6Arrival  Seg6Date
# 0            NaN          NaN       NaN
# 1            NaN          NaN       NaN
# 2            NaN          NaN       NaN
# 3            NaN          NaN       NaN
# 4            NaN          NaN       NaN
# 5            NaN          NaN       NaN
# 6            NaN          NaN       NaN
# 7            NaN          NaN       NaN
# 8            NaN          NaN       NaN
# 9            NaN          NaN       NaN
#
# [10 rows x 22 columns]

# %%
sb = pd.merge(searches, bookings, how='left', left_on=['Seg1Date','Origin','Destination'], right_on=['brd_time','dep_port','arr_port'])

# %%
sb
# Out:
#          Origin Destination    Seg1Date dep_port arr_port brd_time
# 0           TXL         AUH  2013-01-26      NaN      NaN      NaN
# 1           ATH         MIL  2013-01-04      NaN      NaN      NaN
# 2           ICT         SFO  2013-08-02      NaN      NaN      NaN
# 3           RNB         ARN  2013-01-02      NaN      NaN      NaN
# 4           OSL         MAD  2013-03-22      NaN      NaN      NaN
# 5           IAH         BLR  2013-02-14      NaN      NaN      NaN
# 6           CPH         PAR  2013-03-02      NaN      NaN      NaN
# 7           PAR         DUB  2013-02-12      NaN      NaN      NaN
# 8           DUS         ACE  2013-03-30      NaN      NaN      NaN
# 9           FRA         BGW  2013-02-26      NaN      NaN      NaN
# 10          PAR         BUD  2013-03-14      NaN      NaN      NaN
# 11          RIO         POA  2013-02-01      NaN      NaN      NaN
# 12          HKG         MXP  2013-05-21      NaN      NaN      NaN
# 13          BCN         LON  2013-01-30      NaN      NaN      NaN
# 14          CLE         SNN  2013-06-05      NaN      NaN      NaN
# 15          BSB         SLZ  2013-04-23      NaN      NaN      NaN
# 16          PEK         PHL  2013-02-22      NaN      NaN      NaN
# 17          BOS         GRU  2013-01-04      NaN      NaN      NaN
# 18          TBS         IKT  2013-04-02      NaN      NaN      NaN
# 19          LON         HKG  2013-01-05      NaN      NaN      NaN
# 20          MAD         SEA  2013-06-26      NaN      NaN      NaN
# 21          DUS         STN  2013-03-18      NaN      NaN      NaN
# 22          PAD         FUE  2013-01-15      NaN      NaN      NaN
# 23          DUS         IST  2013-03-24      NaN      NaN      NaN
# 24          BHX         VIE  2013-01-15      NaN      NaN      NaN
# 25          CGB         SAO  2013-01-07      NaN      NaN      NaN
# 26          ZRH         BRI  2013-04-06      NaN      NaN      NaN
# 27          RUH         JED  2013-01-04      NaN      NaN      NaN
# 28          UME         CPH  2013-01-06      NaN      NaN      NaN
# 29          FRA         DRS  2013-04-03      NaN      NaN      NaN
# ...         ...         ...         ...      ...      ...      ...
# 20390168    GOT         ZAD  2013-10-30      NaN      NaN      NaN
# 20390169    BGA         PEI  2013-10-19      NaN      NaN      NaN
# 20390170    NYC         MLE  2013-12-19      NaN      NaN      NaN
# 20390171    MAN         DEL  2013-12-29      NaN      NaN      NaN
# 20390172    NYC         ABJ  2014-01-28      NaN      NaN      NaN
# 20390173    OZZ         BRU  2013-10-18      NaN      NaN      NaN
# 20390174    MOW         CDG  2013-11-14      NaN      NaN      NaN
# 20390175    LAX         BKK  2013-12-10      NaN      NaN      NaN
# 20390176    SAO         SSA  2013-11-05      NaN      NaN      NaN
# 20390177    SCN         CPH  2014-07-21      NaN      NaN      NaN
# 20390178    GYN         CGH  2013-10-22      NaN      NaN      NaN
# 20390179    ORD         PVR  2013-11-29      NaN      NaN      NaN
# 20390180    FRA         HAM  2013-10-21      NaN      NaN      NaN
# 20390181    SCQ         PRG  2013-11-21      NaN      NaN      NaN
# 20390182    STR         JFK  2013-12-26      NaN      NaN      NaN
# 20390183    SEA         ICN  2014-01-07      NaN      NaN      NaN
# 20390184    FRA         PMI  2013-12-12      NaN      NaN      NaN
# 20390185    FRA         BKK  2013-12-21      NaN      NaN      NaN
# 20390186    MAD         AMS  2014-01-10      NaN      NaN      NaN
# 20390187    TRD         SRP  2013-10-23      NaN      NaN      NaN
# 20390188    MEL         MCT  2013-10-15      NaN      NaN      NaN
# 20390189    PRG         SKG  2014-01-04      NaN      NaN      NaN
# 20390190    MEL         AMD  2013-12-26      NaN      NaN      NaN
# 20390191    ALC         BRS  2013-11-01      NaN      NaN      NaN
# 20390192    ADL         AKL  2013-12-18      NaN      NaN      NaN
# 20390193    GOT         NBO  2013-12-05      NaN      NaN      NaN
# 20390194    DUS         ALA  2013-12-16      NaN      NaN      NaN
# 20390195    KWI         LHR  2013-11-26      NaN      NaN      NaN
# 20390196    MFE         MAD  2014-05-30      NaN      NaN      NaN
# 20390197    VIE          HA         NaN      NaN      NaN      NaN
#
# [20390198 rows x 6 columns]

# %%
sb['dep_port'].notnull()
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# 5           False
# 6           False
# 7           False
# 8           False
# 9           False
# 10          False
# 11          False
# 12          False
# 13          False
# 14          False
# 15          False
# 16          False
# 17          False
# 18          False
# 19          False
# 20          False
# 21          False
# 22          False
# 23          False
# 24          False
# 25          False
# 26          False
# 27          False
# 28          False
# 29          False
#             ...
# 20390168    False
# 20390169    False
# 20390170    False
# 20390171    False
# 20390172    False
# 20390173    False
# 20390174    False
# 20390175    False
# 20390176    False
# 20390177    False
# 20390178    False
# 20390179    False
# 20390180    False
# 20390181    False
# 20390182    False
# 20390183    False
# 20390184    False
# 20390185    False
# 20390186    False
# 20390187    False
# 20390188    False
# 20390189    False
# 20390190    False
# 20390191    False
# 20390192    False
# 20390193    False
# 20390194    False
# 20390195    False
# 20390196    False
# 20390197    False
# Name: dep_port, Length: 20390198, dtype: bool
